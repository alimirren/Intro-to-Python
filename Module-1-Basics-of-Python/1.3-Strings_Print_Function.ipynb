# %% [markdown]
# # Lecture 3 - Print Function and Strings
#
# ***
#
# * The built-in **`print` function** displays its argument(s) as a line of text

# %%
print('Hello, World!')
# Out:
# Hello, World!

# %% [markdown]
# * May enclose a string in double quotes (`"`).

# %%
print("Yay double quotes!")
# Out:
# Yay double quotes!

# %% [markdown]
# * Python programmers generally prefer single quotes.
# * When `print` completes its task, it positions the screen cursor at the beginning of the next line.

# %% [markdown]
# ### Printing a Comma-Separated List of Items

# %%
print("Hey", "there" + "!", "How", "are", "you", "doing" + "?")
# Out:
# Hey there! How are you doing?

# %% [markdown]
# * Displays each argument separated from the next by a space.

# %% [markdown]
# ### Printing Many Lines of Text with One Statement
# * A backslash (`\`) in a string is the **escape character**.
# * The backslash and the character immediately following it form an **escape sequence**.
# * `\n` represents the **newline character** escape sequence, which tells `print` to move the output cursor to the next line.

# %%
print("\"Double quotes in double quotes?!\"")
print('I\'ll meet you\nat the new line\nhehe')
print('Look at \tthat biiiig space')
# Out:
# "Double quotes in double quotes?!"
# I'll meet you
# at the new line
# hehe
# Look at 	that biiiig space

# %% [markdown]
# ### Other Escape Sequences
# | Escape sequence | Description
# | :------- | :------------
# | `\n` | Insert a newline character in a string. When the string is displayed, for each newline, move the screen cursor to the beginning of the next line.
# | `\t` | Insert a horizontal tab. When the string is displayed, for each tab, move the screen cursor to the next tab stop.
# | `\\` | Insert a backslash character in a string.
# | `\"` | Insert a double quote character in a string.
# | `\'` | Insert a single quote character in a string.

# %% [markdown]
# ### Ignoring a Line Break in a Long String
# * Can split a long string (or a long statement) over several lines by using the **\ continuation character** as the last character on a line to ignore the line break.

# %%
print('yadayadayadayadayadayadayadayadayadayadayadayada \
woah a backslash can split the string!!!!!! no it can\'t')
# Out:
# yadayadayadayadayadayadayadayadayadayadayadayada woah a backslash can split the string!!!!!! no it can't

# %% [markdown]
# * In this case, `\` is not the escape character because another character does not follow it.

# %% [markdown]
# ### Printing the Value of an Expression

# %%
print('Sum is', 7 + 3)
# Out:
# Sum is 10

# %% [markdown]
# ***
# ## Triple Quoted Strings
# * Delimited by **`"""`** or **`'''`**, but the _Style Guide for Python Code_ recommends **`"""`**.
# * Used for:
#     * multiline strings
#     * strings containing single or double quotes
#     * **docstrings**&mdash;the recommended way to document the purposes of certain program components.
#
# ### Including Quotes in Strings (1 of 3)
# * A string delimited by single quotes may include double-quote characters, but not single quotes, unless you use the `\'` escape sequence.

# %%
print('"hi"')
# Out:
# "hi"

# %%
print(''hi'')
# Out:
#   File "/tmp/ipython-input-3341547667.py", line 1
#     print(''hi'')
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print('\'hi\'')
# Out:
# 'hi'

# %% [markdown]
# ### Including Quotes in Strings (2 of 3)
# * A string delimited by double quotes may include single quote characters, but not double quotes, unless you use the `\"` escape sequence.

# %%
print("Display the name O'Brian")
# Out:
# Display the name O'Brian

# %%
print("Display \"hi\" in quotes")
# Out:
# Display "hi" in quotes

# %% [markdown]
# ### Including Quotes in Strings (3 of 3)
# * Triple-quoted strings may contain both single and double quotes.

# %%
print("""Display "hi" and 'bye' in quotes""")
# Out:
# Display "hi" and 'bye' in quotes

# %% [markdown]
# ### Multiline Strings (1 of 2)

# %%
triple_quoted_string = """This is a triple-quoted
string that spans two lines"""
print(triple_quoted_string)
# Out:
# This is a triple-quoted
# string that spans two lines

# %% [markdown]
# * IPython knows that the string is incomplete because we did not type the closing `"""` before we pressed _Enter_.
# * IPython displays a **continuation prompt `...:`** at which you can input the multiline string’s next line.
# * This continues until you enter the ending `"""` and press _Enter_.
#
# ### Multiline Strings (2 of 2)

# %%
print(triple_quoted_string)
# Out:
# This is a triple-quoted
# string that spans two lines

# %%
print("Thid is a triple-quoted\nstring that spans on two lines")
# Out:
# Thid is a triple-quoted
# string that spans on two lines

# %%
triple_quoted_string
# Out:
# 'This is a triple-quoted\nstring that spans two lines'

# %% [markdown]
# ***
# ## Printing Variables in a String
#
# Suppose we wanted to provide a side length $a$, and print out the area of a square.

# %%
side = 1.5
area = side ** 2
print("The area of the square is", area)
# Out:
# The area of the square is 2.25

# %% [markdown]
# * In the preceeding cell we had to hard code the area to be 4. What if we change the side length?
# * We can use `format()` to include the variable `side` in the printed string

# %%
print("The area of the square is {}".format(area))
# Out:
# The area of the square is 2.25

# %% [markdown]
# ***
# # CLASSWORK
#
# 1. **Fill-in** the missing word:
#   * The PRINT function instructs the computer to display information on the screen
#   * Values of the STRING data type contain a sequence of characters.
#   * Multiline strings are enclosed in TRIPLE quotes.
#
# 1. Write an expression which displays the type of `"word"`
#
#
#     type('"word"')
# 1. Print using only one `print` statement:
# ```
# I study
# at John Jay
# ```
#     print("I study\natJohn Jay")
# 1. Print out `ababab@gmail.com` using only the two strings `ab` and `@gmail.com`.
#
#     print('ab' * 3 + '@gmail.com')
#
# 1. Complete the following steps:
#   * Define a variable called `length` and initialize its value to 2.
#
#     length = 2
#   * Define a variable called `width` and initialize its value to 5.
#
#     width = 5
#   * Define a variable called `area` with value `length * width`.
#
#     area = length * width
#   * Print out the following statement `The area of the rectangle is {}` where the value of `area` goes inside the curly braces (use the `.format()` in-built method)
#
#     print(The area of the rectangle is {}".format(area))
#   * Now change `length` to 3.4 and `width` to 5.2 and print out the statement again.

# %%
length = 2
width = 5
area = length * width

# %%
print('The area of the rectangle is {}'.format(area))
length = 3.4
width = 5.2
area = length * width
print('The area of the rectangle is {}'.format(area))
# Out:
# The area of the rectangle is 10
# The area of the rectangle is 17.68

# %% [markdown]
# ------
# &copy;1992&ndash;2020 by Pearson Education, Inc. All Rights Reserved. This content is based on Chapter 2 of the book [**Intro to Python for Computer Science and Data Science: Learning to Program with AI, Big Data and the Cloud**](https://amzn.to/2VvdnxE).
#
# DISCLAIMER: The authors and publisher of this book have used their
# best efforts in preparing the book. These efforts include the
# development, research, and testing of the theories and programs
# to determine their effectiveness. The authors and publisher make
# no warranty of any kind, expressed or implied, with regard to these
# programs or to the documentation contained in these books. The authors
# and publisher shall not be liable in any event for incidental or
# consequential damages in connection with, or arising out of, the
# furnishing, performance, or use of these programs.
