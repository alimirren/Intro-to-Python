# %% [markdown]
# # 4.3 - Strings, A Deeper Look (8.4-8.10)
#
# ***
#
# ## 8.4 Stripping Whitespace from Strings
# * Methods for removing whitespace from the ends of a string each return a new string

# %% [markdown]
# ### Removing Leading and Trailing Whitespace
# * **`strip`** removes leading and trailing whitespace

# %%
sentence = '\t  \n  This is a test string. \t\t \n'

# %%
print(sentence.strip())

# %% [markdown]
# ### Removing Leading Whitespace
# * **`lstrip`** removes only leading whitespace

# %%
sentence.lstrip()
# Out:
# 'This is a test string. \t\t \n'

# %% [markdown]
# ### Removing Trailing Whitespace
# * **`rstrip`** removes only trailing whitespace

# %%
sentence.rstrip()
# Out:
# '\t  \n  This is a test string.'

# %%
sentence
# Out:
# '\t  \n  This is a test string. \t\t \n'

# %% [markdown]
# ***
# ## 8.5 Changing Character Case
#
# ### Capitalizing Only a String’s First Character
# * Method **`capitalize`** returns a new string with only the first letter capitalized (sometimes called **sentence capitalization**)

# %%
'happy birthday'.capitalize()
# Out:
# 'Happy birthday'

# %% [markdown]
# ### Capitalizing the First Character of Every Word in a String
# * Method **`title`** returns a new string with only the first character of each word capitalized (sometimes called **book-title capitalization**)

# %%
'strings: a deeper look'.title()
# Out:
# 'Strings: A Deeper Look'

# %% [markdown]
# ***
# ## 8.6 Comparison Operators for Strings
# * Strings may be compared with the comparison operators
# * Strings are compared based on their underlying integer numeric values
# * Can check integer codes with `ord`

# %%
print(f'A: {ord("A")}; a: {ord("a")}')
# Out:
# A: 65; a: 97

# %% [markdown]
# * Compare the strings `'Orange'` and `'orange'` using the comparison operators

# %%
'Orange' == 'orange'
# Out:
# False

# %%
'Orange' == 'Orange'
# Out:
# True

# %%
'Orange' < 'orange'
# Out:
# True

# %% [markdown]
# ***
# ## 8.7 Searching for Substrings
# * Can search a string for a **substring to
#     * count number of occurrences
#     * determine whether a string contains a substring
#     * determine the index at which a substring resides in a string
# * Each method shown in this section compares characters lexicographically using their underlying numeric values

# %% [markdown]
# ### Counting Occurrences
# * **`count`** returns the number of times its argument occurs in a string

# %%
sentence = 'to be or not to be that is the question'

# %%
sentence.count("to")
# Out:
# 2

# %% [markdown]
# ***
# ## 8.8 Replacing Substrings
# * A common text manipulation is to locate a substring and replace its value
# * **`replace`** searches a string for the substring in its first argument and replaces _each_ occurrence with the substring in its second argument
# * Can receive an optional third argument specifying the maximum number of replacements

# %%
values = '1\t2\t3\t4\t5'

# %%
values.replace("\t", ", ")
# Out:
# '1, 2, 3, 4, 5'

# %% [markdown]
# ***
# ## 8.9 Splitting Strings
# * Tokens typically are separated by whitespace characters such as blank, tab and newline, though other characters may be used—the separators are known as **delimiters**

# %% [markdown]
# ### Splitting Strings
# * To tokenize a string at a custom delimiter, specify the delimiter string that `split` uses to tokenize the string
# * The default delimiter is whitespace.

# %%
sentence = "It is a universal truth"

# %%
sentence.split()
# Out:
# ['It', 'is', 'a', 'universal', 'truth']

# %% [markdown]
# * Other delimiters can be specified.

# %%
paragraph = "Up. Down. Left. Right"

# %%
paragraph.split(". ")
# Out:
# ['Up', 'Down', 'Left', 'Right']

# %% [markdown]
# ***
# ## 8.10 Characters and Character-Testing Methods
# * In Python, a character is simply a one-character string
# * Python provides string methods for testing whether a string matches certain characteristics
# * **`isdigit`** returns `True` if the string on which you call the method contains only the digit characters (`0`–`9`)
#     * Useful for validating data

# %%
'-27'.isdigit()
# Out:
# False

# %%
'27'.isdigit()
# Out:
# True

# %% [markdown]
# * `isalnum` returns `True` if the string on which you call the method is alphanumeric (only digits and letters)

# %%
'A9876'.isalnum()
# Out:
# True

# %%
'123MainStreet'.isalnum()
# Out:
# True

# %% [markdown]
# * Here are some other useful string methods:
#
# | String Method | Description
# | -------- | --------
# | `isalnum()` | Returns `True` if the string contains only _alphanumeric_ characters (i.e., digits and letters).
# | `isalpha()`  | Returns `True` if the string contains only _alphabetic_ characters (i.e., letters).
# | `isdecimal()`  | Returns `True` if the string contains only _decimal integer_ characters (that is, base 10 integers) and does not contain a + or - sign.
# | `isdigit()`  | Returns `True` if the string contains only digits (e.g., '0', '1', '2').
# | `isidentifier()`  | Returns `True` if the string represents a valid _identifier_.
# | `islower()`  | Returns `True` if all alphabetic characters in the string are _lowercase_ characters (e.g., `'a'`, `'b'`, `'c'`).
# | `isnumeric()`  | Returns `True` if the characters in the string represent a _numeric value_ without a + or - sign and without a decimal point.
# | `isspace()`  | Returns `True` if the string contains only _whitespace_ characters.
# | `istitle()`  | Returns `True` if the first character of each word in the string is the only _uppercase_ character in the word.
# | `isupper()`  | Returns `True` if all alphabetic characters in the string are _uppercase_ characters (e.g., `'A'`, `'B'`, `'C'`).

# %% [markdown]
# ***
# # CLASSWORK
#
# 1. **Fill-In**:
#
#   * Strings are a immutable (mutable/immutable), linear (linear/nonlinear) data structure.
#   * Strings can be concatenated with + and repeated with *
#   * Strings consist of a sequence of characters
#   * Describe what the following useful string methods do:
#     * `.count(substr)` - counts how many substrings are in the string
#     * `.replace(old,new)` - replaces one substring with another
#     * `.lstrip()` - removes white space in front
#     * `.split(delim)` - returns a list with all words split with delim
#     * `.isdigit()` - checks if string only consists of digits

# %% [markdown]
# 2. Define strings called `first_name` and `last_name` with your first and last name respectively, then use string operations to concatenate them and then repeat your full name 5 times.

# %%
first_name = "Alina"
last_name = "Mirz"
full_name = first_name + last_name

print(first_name + " " + last_name)
print(full_name * 5)
# Out:
# Alina Mirz
# AlinaMirzAlinaMirzAlinaMirzAlinaMirzAlinaMirz

# %% [markdown]
# 3. For the following string:
# ```
# s = "This is CSC171!"
# ```
#   Complete the following tasks:
#
#   * Access the third character.
#   * Access the second to last character.
#   * Access the 4th through 8th character using slicing.
#   * True or False: the 8th character is alphanumeric. Use a method to verify.
#   * Reverse the string using slicing.
#   * Convert all characters to lowercase
#   * Split the string into words and then save the second word as `word2`

# %%
s = "This is CSC171"

print(s[2])
print(s[-2])
print(s[3:8])
print(s[7].isalnum())
print(s[::-1])
print(s.lower())
words = s.split()
word2 = words[1]
print(word2)
# Out:
# i
# 7
# s is
# False
# 171CSC si sihT
# this is csc171
# is

# %% [markdown]
# ## Advanced
#
# 4. Write a function called `corpus_cleaner` that takes two inputs:
#   * `corpus` - a string
#   * `target_token` - a string that defaults to whitespace `'e'`
#
#   and then performs the following tasks:
#
#   * Removes all non-alphanumeric characters (except whitespace) from `corpus`.
#   * Removes all leading and trailing whitespace from `corpus`
#   * Split the `corpus` into a list of tokens using whitespace.
#   * convert all tokens into lowercase.
#
#   The function should then return a list of how many times `target_token` appears in each token (case-insensitive). Test your function with the following `corpus` and `target_tokens`:
#
#   ```
#   corpus = """
#     Data science is 42% about cleaning data,
#     and 58% about wrangling data.
#     DATA-driven decisions need clean DATA.
#   """
# target_token = "Data"
#   ```

# %% [markdown]
# ------
# &copy;1992&ndash;2020 by Pearson Education, Inc. All Rights Reserved. This content is based on Chapter 5 of the book [**Intro to Python for Computer Science and Data Science: Learning to Program with AI, Big Data and the Cloud**](https://amzn.to/2VvdnxE).
#
# DISCLAIMER: The authors and publisher of this book have used their
# best efforts in preparing the book. These efforts include the
# development, research, and testing of the theories and programs
# to determine their effectiveness. The authors and publisher make
# no warranty of any kind, expressed or implied, with regard to these
# programs or to the documentation contained in these books. The authors
# and publisher shall not be liable in any event for incidental or
# consequential damages in connection with, or arising out of, the
# furnishing, performance, or use of these programs.
