# %% [markdown]
# # 4.5 - Dictionaries (6.2)
# ***
#
# ## 6.2 Dictionaries
# * A dictionary _associates_ keys with values.
# * Each key _maps_ to a specific value.
# * Sample dictionary keys and values:

# %% [markdown]
# | Keys | Key type | Values | Value type
# | :-------- | :-------- | :-------- | :--------
# | Country names | `str` | Internet country codes | `str`
# | Decimal numbers | `int` | Roman numerals | `str`
# | States | `str` | Agricultural products | list of `str`
# | Hospital patients | `str`  | Vital signs | tuple of `int`s and `float`s
# | Baseball players | `str`  | Batting averages | `float`
# | Metric measurements | `str`  | Abbreviations | `str`
# | Inventory codes | `str`  | Quantity in stock | `int`

# %% [markdown]
# ### Unique Keys
# * Keys must be _immutable_ and _unique_.
# * Multiple keys can have the same value.

# %% [markdown]
# ## 6.2.1 Creating a Dictionary
# * Create a dictionary by enclosing in curly braces, `{}`, a comma-separated list of key–value pairs, each of the form _key_: _value_.
# * Create an empty dictionary with `{}`.

# %%
country_codes = {
    "Finland" : "fi",
    "South Africa" : "za",
    "Nepal" : "np"
}

# %%
country_codes
# Out:
# {'Finland': 'fi', 'South Africa': 'za', 'Nepal': 'np'}

# %% [markdown]
# * Dictionaries are _unordered_ collections.
# * Do _not_ write code that depends on the order of the key–value pairs.

# %% [markdown]
# ### Determining if a Dictionary Is Empty

# %%
len(country_codes)
# Out:
# 3

# %% [markdown]
# * Can use a dictionary as a condition to determine if it’s empty—non-empty is `True` and empty is `False`

# %% [markdown]
# ## 6.2.2 Iterating through a Dictionary

# %%
days_per_month = {
    "January" : 31,
    "February": 28,
    "March" : 31
}

# %%
days_per_month
# Out:
# {'January': 31, 'February': 28, 'March': 31}

# %% [markdown]
# * Dictionary method **`items`** returns each key–value pair as a tuple.
# * We can iterate with the general structure:
# ```python
# for key, val in d.items():
#   # key iterates through the keys
#   # val iterates through the values
# ```

# %%
for month, days in days_per_month.items():
  print(f"{month} has {days} days")
# Out:
# January has 31 days
# February has 28 days
# March has 31 days

# %% [markdown]
# ## 6.2.3 Basic Dictionary Operations

# %% [markdown]
# * Intentionally provided the incorrect value `100` for the key `'X'`:

# %%
roman_numerals = {
    "I" : 1,
    "II" : 2,
    "III" : 3,
    "V" : 5,
    "X" : 10
}

# %%
roman_numerals
# Out:
# {'I': 1, 'II': 2, 'III': 3, 'V': 5, 'X': 10}

# %% [markdown]
# ### Accessing the Value Associated with a Key

# %%
roman_numerals['V']
# Out:
# 5

# %% [markdown]
# ### Updating the Value of an Existing Key–Value Pair

# %%
roman_numerals['X'] = 10

# %%
roman_numerals
# Out:
# {'I': 1, 'II': 2, 'III': 3, 'V': 5, 'X': 10}

# %% [markdown]
# ### Adding a New Key–Value Pair

# %%
roman_numerals['L'] = 50

# %%
roman_numerals
# Out:
# {'I': 1, 'II': 2, 'III': 3, 'V': 5, 'X': 10, 'L': 50}

# %% [markdown]
# * String keys are case sensitive.
# * Assigning to a nonexistent key inserts a new key–value pair.

# %% [markdown]
# ### Removing a Key–Value Pair

# %%
del roman_numerals['III']

# %%
roman_numerals
# Out:
# {'I': 1, 'II': 2, 'V': 5, 'X': 10, 'L': 50}

# %% [markdown]
# * Method **`pop`** returns the value for the removed key.

# %%
popped_val = roman_numerals.pop('X')

print(popped_val)
# Out:
# 10

# %%
roman_numerals
# Out:
# {'I': 1, 'II': 2, 'V': 5, 'L': 50}

# %% [markdown]
# ### Attempting to Access a Nonexistent Key

# %%
roman_numerals["III"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-961473629.py in <cell line: 0>()
# ----> 1 roman_numerals["III"]
#
# KeyError: 'III'

# %% [markdown]
# * Method **`get`** returns its argument’s corresponding value or `None` if the key is not found.
# * IPython does not display anything for `None`.
# * `get` with a second argument returns teh second argument if the key is not found.

# %% [markdown]
# ### Testing Whether a Dictionary Contains a Specified Key
#
# * We can use the `in` keyword to test whether a key in inside a dictionary.

# %%
'V' in roman_numerals
# Out:
# True

# %%
'III' in roman_numerals
# Out:
# False

# %% [markdown]
# ## 6.2.4 Dictionary Methods `keys` and `values`
# * `.keys()` method returns an iterable of the dictionaries keys
# * `.values()` method returns an iterable of the dictionaries values.

# %%
months = {
    "January": 1,
    "February" : 2,
    "March" : 3
}

# %%
for month_name in months.keys():
    print(month_name, end='  ')
# Out:
# January  February  March

# %%
for month_number in months.values():
    print(month_number, end='  ')
# Out:
# 1  2  3

# %% [markdown]
# ### Dictionary Views
# * Methods `items`, `keys` and `values` each return a **view** of a dictionary’s data.
# * When you iterate over a **`view`**, it “sees” the dictionary’s **current contents**—it does **not** have its own copy of the data.

# %%
months_view = months.keys() # shallow copy of months

# %%
for key in months_view:
    print(key, end='  ')
# Out:
# January  February  March

# %%
months['December'] = 12

# %%
months
# Out:
# {'January': 1, 'February': 2, 'March': 3, 'December': 12}

# %%
for key in months_view:
    print(key, end='  ')
# Out:
# January  February  March  December

# %% [markdown]
# ### Converting Dictionary Keys, Values and Key–Value Pairs to Lists
#
# * We can convert the iterables into lists using the `list()` constructor.

# %% [markdown]
# ### Processing Keys in Sorted Order
#
# * We can sort the keys of a dictionary using the `sorted()` function.
# * Recall that `sorted` uses the comparison for the object it recieves, so strings are ordered by their encoded value.

# %% [markdown]
# ## 6.2.5 Dictionary Comparisons
# * `==` is `True` if both dictionaries have the same key–value pairs, **_regardless_ of the order in which those key–value pairs were added to each dictionary**.

# %%
country_capitals1 = {'Belgium': 'Brussels',
                     'Haiti': 'Port-au-Prince'}

# %%
country_capitals2 = {'Nepal': 'Kathmandu',
                     'Uruguay': 'Montevideo'}

# %%
country_capitals3 = {'Haiti': 'Port-au-Prince',
                     'Belgium': 'Brussels'}

# %%
country_capitals1 == country_capitals2
# Out:
# False

# %%
country_capitals1 == country_capitals3
# Out:
# True

# %% [markdown]
# ## 6.2.6 Example: Dictionary of Student Grades
# * Script with a dictionary that represents an instructor’s grade book.
# * Maps each student’s name (a string) to a list of integers containing that student’s grades on three exams.

# %%
"""Using a dictionary to represent an instructor's grade book."""

grade_book = {
    "Alice": [92, 85, 100],
    "Bob": [83, 95, 79],
    "Charlie": [91, 89, 82],
    "Dana": [97, 91, 92]
}

# compute average for each student
all_grades_total = 0
all_grades_count = 0

for name, grades in grade_book.items():
  total = sum(grades)
  print(f"Average for {name} is {total / len(grades):.2f}")
  all_grades_total += total
  all_grades_count += len(grades)

print(f"Class average is {all_grades_total / all_grades_count:.2f}")
# Out:
# Average for Alice is 92.33
# Average for Bob is 85.67
# Average for Charlie is 87.33
# Average for Dana is 93.33
# Class average is 89.67

# %% [markdown]
# ## 6.2.7 Example: Word Counts
# * Script that builds a dictionary to count the number of occurrences of each word in a **tokenized** string.
# * Python automatically concatenates strings separated by whitespace in parentheses.

# %%
"""Tokenizing a string and counting unique words."""

text = ('this is sample text with several words '
        'this is more sample text with some different words')

# initialize empty dictionary
word_counts = {}

# count occurrences of each word in text
for word in text.split():
  if word in word_counts:
    word_counts[word] += 1
  else:
    word_counts[word] = 1

# print the results in a nice table using f-strings
print(f"{'WORD':<12}COUNT")
for word,count in sorted(word_counts.items()):
  print(f"{word:<12}{count}")

print("\nNumber of unique words:", len(word_counts))
# Out:
# WORD        COUNT
# different   1
# is          2
# more        1
# sample      2
# several     1
# some        1
# text        2
# this        2
# with        2
# words       2
#
# Number of unique words: 10

# %%
word_counts
# Out:
# {'this': 2,
#  'is': 2,
#  'sample': 2,
#  'text': 2,
#  'with': 2,
#  'several': 1,
#  'words': 2,
#  'more': 1,
#  'some': 1,
#  'different': 1}

# %% [markdown]
# ## 6.2.8 Dictionary Method `update`
# * Can insert and update key–value pairs.
# * Method `update` also can receive an iterable object containing key–value pairs, such as a list of two-element tuples.
# * The `update` method can also use keyword assignment.

# %%
country_codes = {}  # create empty dictionary

# %%
country_codes.update({'South Africa': 'za'})

# %%
country_codes
# Out:
# {'South Africa': 'za'}

# %%
country_codes.update(Australia='au')

# %%
country_codes
# Out:
# {'South Africa': 'za', 'Australia': 'au'}

# %% [markdown]
# ## 6.2.9 Dictionary Comprehensions
# * Convenient notation for quickly generating dictionaries, often by **mapping** one dictionary to another.
# * The expression to the left of the `for` clause specifies a **key–value pair of the form _key_`:` _value_**.
# * In a dictionary with **_unique_ values**, you can **reverse** the key–value pair mappings.

# %%
months = {'January': 1, 'February': 2, 'March': 3}

# %%
months2 = {number:name for name,number in months.items()}

# %%
months2
# Out:
# {1: 'January', 2: 'February', 3: 'March'}

# %% [markdown]
# * A dictionary comprehension also can map a dictionary’s values to new values.

# %%
grades = {'Sue': [98, 87, 94], 'Bob': [84, 95, 91]}

# %%
grades2 = {k: sum(v) / len(v) for k, v in grades.items()} # compute averages

# %%
grades2
# Out:
# {'Sue': 93.0, 'Bob': 90.0}

# %% [markdown]
# ***
# # CLASSWORK
#
# 1. **Fill-In**:
#   * A dictionary can be thought of as an unordered collection in which each value is accessed through its corresponding key.
#   * Dictionary method items() returns each key-value pair as a tuple.
#   * When `key` is already present in a dictionary, the following code does what?
#   ```
#   dictionaryName[key] = value
#   ```
#   * Dictionary method keys() returns an unordered list of the dictionary's keys.
#   * Dictionary method values() returns an unordered list of the dictionary's values.
#   * The `==` comparison evaluations to ???? only if both dictionaries have the same `key:value` pairs, regardless of their order.

# %% [markdown]
# 2. Three students, `Alice`, `Bob` and `Charlie` take an exam, and get the scores of `85`, `90` and `78` respectively.
#   * Create a dictionary called `grades` that stores this data, with the name as the key and the exam score as the value.
#   * Access and print the grade of `Bob`
#   * Iterate over the dictionary and print out all student names.
#   * Iterate over the dictionary and print `"Student: Grade"` for each pair
#   * Update Alice's grade to `88`
#   * Add a new student `Diana` with a grade of `92`
#   * Remove `Charlie` from the dictionary.

# %%
grades = {
    "Alice" : 85,
    "Bob" : 90,
    "Charlie" : 78
}

print(grades["Bob"])

for name in grades.keys():
  print(name)

for name, grade in grades.items():
  print(f"{name}: {grade}")

grades["Alice"] = 88
print(grades)

grades["Diana"] = 92
print(grades)

grades.pop("Charlie")
print(grades)
# Out:
# 90
# Alice
# Bob
# Charlie
# Alice: 85
# Bob: 90
# Charlie: 78
# {'Alice': 88, 'Bob': 90, 'Charlie': 78}
# {'Alice': 88, 'Bob': 90, 'Charlie': 78, 'Diana': 92}
# {'Alice': 88, 'Bob': 90, 'Diana': 92}

# %% [markdown]
# 3. A store sells `apples`, `bananas` and `oranges`. The current stock for each item is `10`, `5` and `8` respectively.
#   * Create a dictionary called `inventory` that stores this data.
#   * Access and print the stock count for `bananas`.
#   * Print all item names using a loop.
#   * Increase the stock of `apples` by `5`.
#   * Add a new item called `pears` with a count of `12`
#   * Remove `bananas` from the inventory.

# %% [markdown]
# 4. Use a **dictionary comprehension** called `cubes` to store the numbers 1-5 with their cubes. Your dictionary should look like:
# ```
# cubes = {
#     1: 1,
#     2: 8,
#     3: 27,
#     4: 64,
#     5: 125
#   }
# ```

# %% [markdown]
# ## Advanced
#
# 5. You’re working with data from a student survey that asked about daily screen time (in hours). The data is stored as a dictionary below:
# ```python
# screen_time = {
#     "Alice": 5,
#     "Bob": 7,
#     "Charlie": 3,
#     "Diana": 6,
#     "Eli": 4
# }
# ```
#   * Iterate over key-value pairs and print a sentence such as `"{} spends {} hours on screens daily"`
#   * Update Eli's screen time to 5 hours.
#   * Remove `Bob` from the dictionary.
#   * Use a dictionary comprehension to create a new dictionary called `above_average` which contains only the students who spend more than the average screen time. (You will need to first calculate the average screen time!)

# %% [markdown]
# ------
# &copy;1992&ndash;2020 by Pearson Education, Inc. All Rights Reserved. This content is based on Chapter 6 of the book [**Intro to Python for Computer Science and Data Science: Learning to Program with AI, Big Data and the Cloud**](https://amzn.to/2VvdnxE).
#
# DISCLAIMER: The authors and publisher of this book have used their
# best efforts in preparing the book. These efforts include the
# development, research, and testing of the theories and programs
# to determine their effectiveness. The authors and publisher make
# no warranty of any kind, expressed or implied, with regard to these
# programs or to the documentation contained in these books. The authors
# and publisher shall not be liable in any event for incidental or
# consequential damages in connection with, or arising out of, the
# furnishing, performance, or use of these programs.
